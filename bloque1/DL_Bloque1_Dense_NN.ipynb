# %% [markdown]
# # Módulo 1: Redes Neuronales Densas
#
# En este cuaderno, exploraremos los fundamentos matemáticos de las redes neuronales densas y su dinámica de entrenamiento.
#
# ---
#
# ## Contenido
#
# 1. Espacios vectoriales, aplicaciones lineales y composiciones
# 2. Aproximación universal
# 3. Descenso de gradiente
# 4. Activaciones no lineales
# 5. Funciones de pérdida

# %% [markdown]
# ## 1. Espacios Vectoriales, Aplicaciones Lineales y Composiciones
#
# Una **capa densa** en una red neuronal es una aplicación lineal:
#
# $$
# f(\mathbf{x}) = W \mathbf{x} + b
# $$
#
# donde:
#
# * $\mathbf{x} \in \mathbb{R}^n$ es el vector de entrada,
# * $W \in \mathbb{R}^{m \times n}$ es la matriz de pesos,
# * $b \in \mathbb{R}^m$ es el sesgo.
#
# Cuando apilamos capas con funciones no lineales, obtenemos una composición:
#
# $$
# f(\mathbf{x}) = \sigma \big(W_2 (\sigma(W_1 \mathbf{x} + b_1)) + b_2 \big)
# $$
#
# donde $\sigma$ es una función de activación no lineal.

# %%
import tensorflow as tf
import numpy as np
import math

import matplotlib.pyplot as plt

# %%
# Ejemplo: Una transformación lineal simple
x = tf.constant([[1.0, 2.0]], dtype=tf.float32)  # vector de entrada

#x = tf.Variable([[1.0, 2.0]], dtype=tf.float32)

#x = np.array([[1.0, 2.0]])
#x = tf.convert_to_tensor(x, dtype=tf.float32)

W = tf.constant([[2.0, -1.0],
                 [0.5, 3.0]], dtype=tf.float32)  # matrix de pesos
b = tf.constant([1.0, -2.0], dtype=tf.float32)   # bias

y = tf.matmul(x, W) + b
y
# Out:
# I0000 00:00:1784854311.358300    7983 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11892 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:07:00.0, compute capability: 8.9
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[4., 3.]], dtype=float32)>

# %%
tf.keras.activations.sigmoid(y)
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[0.98201376, 0.95257413]], dtype=float32)>

# %% [markdown]
# ## 2. Aproximación Universal
#
# * **Teorema de Aproximación Universal**: Una red neuronal feedforward con una sola capa oculta
#   que contiene un número finito de neuronas puede aproximar cualquier función continua en subconjuntos compactos de $\mathbb{R}^n$,
#   dada una función de activación (por ejemplo, sigmoide, ReLU).

# %%
# Datos
X = np.linspace(-2*np.pi, 2*np.pi, 200).reshape(-1, 1)
y_true = np.sin(X)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y_true, epochs=500, verbose=1)

y_pred = model.predict(X)
# Out:
# /home/gibran/anaconda3/envs/tf219/lib/python3.10/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784846533.496959  557205 service.cc:152] XLA service 0x7631e8003110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1784846533.496985  557205 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2026-07-23 16:42:13.526660: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1784846533.609110  557205 cuda_dnn.cc:529] Loaded cuDNN version 91001
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 5s 907ms/step - loss: 0.4396
# I0000 00:00:1784846533.841332  557205 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.4910
# Epoch 2/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4955
# Epoch 3/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4431
# Epoch 4/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4514
# Epoch 5/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4258
# Epoch 6/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3927
# Epoch 7/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3989
# Epoch 8/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3756
# Epoch 9/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3869
# Epoch 10/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3532
# Epoch 11/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3483
# Epoch 12/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3393
# Epoch 13/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3370
# Epoch 14/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3330
# Epoch 15/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3193
# Epoch 16/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3285
# Epoch 17/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3062
# Epoch 18/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2983
# Epoch 19/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2891
# Epoch 20/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2828
# Epoch 21/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2790
# Epoch 22/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2685
# Epoch 23/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2786
# Epoch 24/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2754
# Epoch 25/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2631
# Epoch 26/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2726
# Epoch 27/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2430
# Epoch 28/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2543
# Epoch 29/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2523
# Epoch 30/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2469
# Epoch 31/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2494
# Epoch 32/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2417
# Epoch 33/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2476
# Epoch 34/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2378
# Epoch 35/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2203
# Epoch 36/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2263
# Epoch 37/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2192
# Epoch 38/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2185
# Epoch 39/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2187
# Epoch 40/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2246
# Epoch 41/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2039
# Epoch 42/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2074
# Epoch 43/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2189
# Epoch 44/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1970
# Epoch 45/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2158
# Epoch 46/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2027
# Epoch 47/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1878
# Epoch 48/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1952
# Epoch 49/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1793
# Epoch 50/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1784
# Epoch 51/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2172
# Epoch 52/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1831
# Epoch 53/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1984
# Epoch 54/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1846
# Epoch 55/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1812
# Epoch 56/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1977
# Epoch 57/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1834
# Epoch 58/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1816
# Epoch 59/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1732
# Epoch 60/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1713
# Epoch 61/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1902
# Epoch 62/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1964
# Epoch 63/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1717
# Epoch 64/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1915
# Epoch 65/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1626
# Epoch 66/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1585
# Epoch 67/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1824
# Epoch 68/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1880
# Epoch 69/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1680
# Epoch 70/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1584
# Epoch 71/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1633
# Epoch 72/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1668
# Epoch 73/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1708
# Epoch 74/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1519
# Epoch 75/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484
# Epoch 76/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1436
# Epoch 77/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1684
# Epoch 78/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1424
# Epoch 79/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1528
# Epoch 80/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1476
# Epoch 81/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1358
# Epoch 82/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1446
# Epoch 83/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1449
# Epoch 84/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1504
# Epoch 85/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1445
# Epoch 86/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1426
# Epoch 87/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1461
# Epoch 88/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1323
# Epoch 89/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479
# Epoch 90/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481
# Epoch 91/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1418
# Epoch 92/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1395
# Epoch 93/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1382
# Epoch 94/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1441
# Epoch 95/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1179
# Epoch 96/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1379
# Epoch 97/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1376
# Epoch 98/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1280
# Epoch 99/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1356
# Epoch 100/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1320
# Epoch 101/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1334
# Epoch 102/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1202
# Epoch 103/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1391
# Epoch 104/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1231
# Epoch 105/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1233
# Epoch 106/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1240
# Epoch 107/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1287
# Epoch 108/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1237
# Epoch 109/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1191
# Epoch 110/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1180
# Epoch 111/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1102
# Epoch 112/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1360
# Epoch 113/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1355
# Epoch 114/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1108
# Epoch 115/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1229
# Epoch 116/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1094
# Epoch 117/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1069
# Epoch 118/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1250
# Epoch 119/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1201
# Epoch 120/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1147
# Epoch 121/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1009
# Epoch 122/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1039
# Epoch 123/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1096
# Epoch 124/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1111
# Epoch 125/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1148
# Epoch 126/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1097
# Epoch 127/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1171
# Epoch 128/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1046
# Epoch 129/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0895
# Epoch 130/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1140
# Epoch 131/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0993
# Epoch 132/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0934
# Epoch 133/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0916
# Epoch 134/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1000
# Epoch 135/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0968
# Epoch 136/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1064
# Epoch 137/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0919
# Epoch 138/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1096
# Epoch 139/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0995
# Epoch 140/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1001
# Epoch 141/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1065
# Epoch 142/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1088
# Epoch 143/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1069
# Epoch 144/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0996
# Epoch 145/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0912
# Epoch 146/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1025
# Epoch 147/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0875
# Epoch 148/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
# Epoch 149/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# Epoch 150/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0893
# Epoch 151/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0906
# Epoch 152/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0880
# Epoch 153/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0907
# Epoch 154/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0873
# Epoch 155/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0868
# Epoch 156/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0912
# Epoch 157/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1025
# Epoch 158/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# Epoch 159/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0856
# Epoch 160/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0908
# Epoch 161/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0913
# Epoch 162/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0875
# Epoch 163/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0795
# Epoch 164/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0890
# Epoch 165/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0876
# Epoch 166/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0848
# Epoch 167/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0764
# Epoch 168/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0881
# Epoch 169/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0838
# Epoch 170/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0805
# Epoch 171/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0816
# Epoch 172/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0773
# Epoch 173/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0899
# Epoch 174/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0783
# Epoch 175/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0857
# Epoch 176/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0871
# Epoch 177/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0830
# Epoch 178/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0764
# Epoch 179/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0810
# Epoch 180/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0846
# Epoch 181/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0846
# Epoch 182/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0721
# Epoch 183/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0755
# Epoch 184/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0869
# Epoch 185/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0784
# Epoch 186/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0735
# Epoch 187/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0749
# Epoch 188/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0814
# Epoch 189/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0888
# Epoch 190/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0715
# Epoch 191/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0744
# Epoch 192/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0725
# Epoch 193/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0723
# Epoch 194/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0824
# Epoch 195/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0744
# Epoch 196/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0805
# Epoch 197/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0778
# Epoch 198/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0778
# Epoch 199/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0671
# Epoch 200/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0814
# Epoch 201/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0743
# Epoch 202/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0712
# Epoch 203/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0657
# Epoch 204/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0811
# Epoch 205/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0724
# Epoch 206/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0709
# Epoch 207/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0717
# Epoch 208/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0673
# Epoch 209/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0719
# Epoch 210/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0712
# Epoch 211/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0757
# Epoch 212/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0758
# Epoch 213/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0772
# Epoch 214/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0798
# Epoch 215/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0784
# Epoch 216/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0686
# Epoch 217/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0588
# Epoch 218/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0768
# Epoch 219/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0714
# Epoch 220/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0736
# Epoch 221/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0682
# Epoch 222/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0782
# Epoch 223/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0752
# Epoch 224/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0650
# Epoch 225/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0769
# Epoch 226/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0753
# Epoch 227/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0793
# Epoch 228/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0725
# Epoch 229/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0813
# Epoch 230/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0691
# Epoch 231/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0734
# Epoch 232/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0676
# Epoch 233/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0730
# Epoch 234/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0762
# Epoch 235/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0677
# Epoch 236/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0641
# Epoch 237/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0670
# Epoch 238/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0731
# Epoch 239/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0671
# Epoch 240/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0725
# Epoch 241/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0724
# Epoch 242/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0652
# Epoch 243/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0779
# Epoch 244/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0702
# Epoch 245/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0668
# Epoch 246/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0728
# Epoch 247/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0690
# Epoch 248/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0682
# Epoch 249/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0702
# Epoch 250/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0717
# Epoch 251/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0721
# Epoch 252/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0663
# Epoch 253/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0760
# Epoch 254/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0711
# Epoch 255/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0630
# Epoch 256/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0615
# Epoch 257/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0720
# Epoch 258/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0637
# Epoch 259/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0709
# Epoch 260/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0682
# Epoch 261/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0602
# Epoch 262/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0623
# Epoch 263/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0688
# Epoch 264/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0708
# Epoch 265/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0704
# Epoch 266/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0666
# Epoch 267/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0667
# Epoch 268/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0687
# Epoch 269/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0710
# Epoch 270/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0738
# Epoch 271/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0623
# Epoch 272/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0653
# Epoch 273/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0692
# Epoch 274/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0634
# Epoch 275/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0620
# Epoch 276/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0732
# Epoch 277/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0684
# Epoch 278/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0657
# Epoch 279/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0708
# Epoch 280/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0720
# Epoch 281/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0665
# Epoch 282/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0665
# Epoch 283/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0717
# Epoch 284/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608
# Epoch 285/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0704
# Epoch 286/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0615
# Epoch 287/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630
# Epoch 288/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0628
# Epoch 289/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0713
# Epoch 290/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0590
# Epoch 291/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0674
# Epoch 292/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0633
# Epoch 293/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0617
# Epoch 294/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0652
# Epoch 295/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0647
# Epoch 296/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0622
# Epoch 297/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0617
# Epoch 298/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0667
# Epoch 299/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0642
# Epoch 300/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0724
# Epoch 301/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0701
# Epoch 302/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0722
# Epoch 303/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0614
# Epoch 304/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0647
# Epoch 305/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0665
# Epoch 306/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0696
# Epoch 307/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0720
# Epoch 308/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0673
# Epoch 309/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0672
# Epoch 310/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0621
# Epoch 311/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630
# Epoch 312/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630
# Epoch 313/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0647
# Epoch 314/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0637
# Epoch 315/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0747
# Epoch 316/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0633
# Epoch 317/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0633
# Epoch 318/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0675
# Epoch 319/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0592
# Epoch 320/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0654
# Epoch 321/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0622
# Epoch 322/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0702
# Epoch 323/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0651
# Epoch 324/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0655
# Epoch 325/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0671
# Epoch 326/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0620
# Epoch 327/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0673
# Epoch 328/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0704
# Epoch 329/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0607
# Epoch 330/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0683
# Epoch 331/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0695
# Epoch 332/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0633
# Epoch 333/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0677
# Epoch 334/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0673
# Epoch 335/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0646
# Epoch 336/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0611
# Epoch 337/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0636
# Epoch 338/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0671
# Epoch 339/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0711
# Epoch 340/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630
# Epoch 341/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0627
# Epoch 342/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0617
# Epoch 343/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0599
# Epoch 344/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0653
# Epoch 345/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0651
# Epoch 346/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0643
# Epoch 347/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0697
# Epoch 348/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0655
# Epoch 349/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0645
# Epoch 350/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0580
# Epoch 351/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0600
# Epoch 352/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0621
# Epoch 353/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0710
# Epoch 354/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0591
# Epoch 355/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0650
# Epoch 356/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0642
# Epoch 357/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0602
# Epoch 358/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0637
# Epoch 359/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0630
# Epoch 360/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0684
# Epoch 361/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0629
# Epoch 362/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0661
# Epoch 363/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0585
# Epoch 364/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0668
# Epoch 365/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0675
# Epoch 366/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0648
# Epoch 367/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0649
# Epoch 368/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0633
# Epoch 369/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0670
# Epoch 370/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630
# Epoch 371/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0637
# Epoch 372/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0615
# Epoch 373/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0619
# Epoch 374/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0656
# Epoch 375/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0627
# Epoch 376/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0599
# Epoch 377/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0597
# Epoch 378/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0600
# Epoch 379/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0669
# Epoch 380/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0615
# Epoch 381/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0667
# Epoch 382/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0676
# Epoch 383/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0649
# Epoch 384/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0606
# Epoch 385/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0622
# Epoch 386/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0638
# Epoch 387/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0649
# Epoch 388/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0644
# Epoch 389/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0663
# Epoch 390/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0650
# Epoch 391/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0590
# Epoch 392/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0669
# Epoch 393/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0666
# Epoch 394/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0607
# Epoch 395/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0641
# Epoch 396/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0591
# Epoch 397/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0614
# Epoch 398/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0609
# Epoch 399/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0597
# Epoch 400/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608
# Epoch 401/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0626
# Epoch 402/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0598
# Epoch 403/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0665
# Epoch 404/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0641
# Epoch 405/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0621
# Epoch 406/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0613
# Epoch 407/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0651
# Epoch 408/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0668
# Epoch 409/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0596
# Epoch 410/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0593
# Epoch 411/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0617
# Epoch 412/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0601
# Epoch 413/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0574
# Epoch 414/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0600
# Epoch 415/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0597
# Epoch 416/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0602
# Epoch 417/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608
# Epoch 418/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0583
# Epoch 419/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0654
# Epoch 420/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0619
# Epoch 421/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0636
# Epoch 422/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0622
# Epoch 423/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0625
# Epoch 424/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608
# Epoch 425/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0579
# Epoch 426/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0640
# Epoch 427/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0627
# Epoch 428/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0579
# Epoch 429/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0574
# Epoch 430/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0618
# Epoch 431/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0555
# Epoch 432/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0636
# Epoch 433/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0578
# Epoch 434/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0593
# Epoch 435/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0672
# Epoch 436/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0557
# Epoch 437/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0576
# Epoch 438/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0595
# Epoch 439/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0615
# Epoch 440/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0623
# Epoch 441/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0624
# Epoch 442/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0647
# Epoch 443/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0586
# Epoch 444/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0584
# Epoch 445/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0614
# Epoch 446/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0631
# Epoch 447/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0577
# Epoch 448/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0537
# Epoch 449/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0588
# Epoch 450/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630
# Epoch 451/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0607
# Epoch 452/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0597
# Epoch 453/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0588
# Epoch 454/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0642
# Epoch 455/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0610
# Epoch 456/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0562
# Epoch 457/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0573
# Epoch 458/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0585
# Epoch 459/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0590
# Epoch 460/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0585
# Epoch 461/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0623
# Epoch 462/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0568
# Epoch 463/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0665
# Epoch 464/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0572
# Epoch 465/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0595
# Epoch 466/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0641
# Epoch 467/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0623
# Epoch 468/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0541
# Epoch 469/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0646
# Epoch 470/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0606
# Epoch 471/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0605
# Epoch 472/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0626
# Epoch 473/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0560
# Epoch 474/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0634
# Epoch 475/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0599
# Epoch 476/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0576
# Epoch 477/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0567
# Epoch 478/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0568
# Epoch 479/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0578
# Epoch 480/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0631
# Epoch 481/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0600
# Epoch 482/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0559
# Epoch 483/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0571
# Epoch 484/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0566
# Epoch 485/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0566
# Epoch 486/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0615
# Epoch 487/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0579
# Epoch 488/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0583
# Epoch 489/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0604
# Epoch 490/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0553
# Epoch 491/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0627
# Epoch 492/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0562
# Epoch 493/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0594
# Epoch 494/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0617
# Epoch 495/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0554
# Epoch 496/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0606
# Epoch 497/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0611
# Epoch 498/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0545
# Epoch 499/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0582
# Epoch 500/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0634
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
plt.plot(X, y_true, label="sin(x)")
plt.plot(X, y_pred, label="NN approx")
plt.legend()
plt.show()

# %%
def taylor_sin(x, order):
    n_terms = (order // 2) + 1  
    out = np.zeros_like(x)
    for k in range(n_terms):
        p = 2*k + 1
        out = out + ((-1)**k) * np.power(x, p) / math.factorial(p)
    return out


taylor_preds = taylor_sin(X, 5)

# %%
plt.plot(X, y_true, label="sin(x)")
plt.plot(X, y_pred, label="NN approx")
plt.plot(X, taylor_preds, label="Taylor approx")
plt.legend()
plt.show()

# %%
def mse(a, b):
    return float(np.mean((a - b)**2))

def max_abs_err(a, b):
    return float(np.max(np.abs(a - b)))

nn_mse = mse(y_pred, y_true)
nn_max = max_abs_err(y_pred, y_true)

t_mse = mse(taylor_preds, y_true)
t_max = max_abs_err(taylor_preds, y_true)


metrics = {
    'NeuralNet': {'MSE': nn_mse, 'MaxAbsErr': nn_max},
    'Taylor': {'MSE': t_mse, 'MaxAbsErr': t_max},
}

# %%
print("{:<15s}  {:>12s}  {:>12s}".format("Approximator", "MSE", "Max|err|"))
for k, v in metrics.items():
    print("{:<15s}  {:>12.6e}  {:>12.6e}".format(k, v['MSE'], v['MaxAbsErr']))
# Out:
# Approximator              MSE      Max|err|
# NeuralNet        5.774673e-02  6.730351e-01
# Taylor           1.720090e+02  4.654673e+01

# %% [markdown]
# ## 3. Descenso de Gradiente
#
# Minimizamos una función de pérdida $L(\theta)$ usando **descenso de gradiente**:
#
# $$
# \theta_{t+1} = \theta_t - \lambda \nabla L(\theta_t)
# $$
#
# Variantes:
#
# * SGD (descenso de gradiente estocástico)
# * Momentum
# * RMSProp
# * Adam
#
# Cada una modifica la dinámica de actualización dependiendo de la curvatura de la función de pérdida.

# %%
L = sum((f(x, W, b) - y)²) / n

dL / dW1 
dL / db1
dL / dW2
dL / db2

# %%
def F(x):
    return (x + 1)**2

# %%
x = tf.Variable(initial_value=2.0, name='x', trainable=True, dtype=tf.float32)

optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)

# %%
for _ in range(1000):

    with tf.GradientTape() as tape:
        y = F(x) 
        
    gradients = tape.gradient(y, [x])
    optimizer.apply_gradients(zip(gradients, [x]))
    print("y:",y.numpy(), "x:",x.numpy())
# Out:
# y: 9.0 x: 1.4
# y: 5.7600007 x: 0.91999996
# y: 3.6864 x: 0.53599995
# y: 2.359296 x: 0.22879994
# y: 1.5099493 x: -0.016960055
# y: 0.9663676 x: -0.21356805
# y: 0.61847526 x: -0.37085444
# y: 0.39582413 x: -0.49668354
# y: 0.25332746 x: -0.59734684
# y: 0.16212957 x: -0.6778775
# y: 0.10376291 x: -0.742302
# y: 0.06640826 x: -0.7938416
# y: 0.042501286 x: -0.8350733
# y: 0.02720082 x: -0.8680586
# y: 0.017408527 x: -0.8944469
# y: 0.011141455 x: -0.9155575
# y: 0.0071305353 x: -0.932446
# y: 0.0045635425 x: -0.9459568
# y: 0.0029206646 x: -0.9567655
# y: 0.0018692244 x: -0.9654124
# y: 0.0011963035 x: -0.9723299
# y: 0.00076563365 x: -0.9778639
# y: 0.0004900066 x: -0.9822911
# y: 0.00031360507 x: -0.98583287
# y: 0.00020070758 x: -0.9886663
# y: 0.00012845284 x: -0.99093306
# y: 8.220939e-05 x: -0.9927465
# y: 5.2613665e-05 x: -0.9941972
# y: 3.3672604e-05 x: -0.99535775
# y: 2.1550468e-05 x: -0.9962862
# y: 1.3792211e-05 x: -0.99702895
# y: 8.827157e-06 x: -0.99762315
# y: 5.649437e-06 x: -0.9980985
# y: 3.6157303e-06 x: -0.9984788
# y: 2.31414e-06 x: -0.998783
# y: 1.4811076e-06 x: -0.9990264
# y: 9.478624e-07 x: -0.99922115
# y: 6.066134e-07 x: -0.9993769
# y: 3.882623e-07 x: -0.9995015
# y: 2.4847597e-07 x: -0.99960124
# y: 1.5900561e-07 x: -0.999681
# y: 1.0176359e-07 x: -0.9997448
# y: 6.514087e-08 x: -0.9997958
# y: 4.169989e-08 x: -0.9998366
# y: 2.6691826e-08 x: -0.9998693
# y: 1.7085885e-08 x: -0.99989545
# y: 1.09299805e-08 x: -0.9999164
# y: 6.9931936e-09 x: -0.9999331
# y: 4.4724544e-09 x: -0.9999465
# y: 2.8649225e-09 x: -0.9999572
# y: 1.8315092e-09 x: -0.9999658
# y: 1.1705339e-09 x: -0.99997264
# y: 7.4848927e-10 x: -0.9999781
# y: 4.7851145e-10 x: -0.9999825
# y: 3.0708236e-10 x: -0.999986
# y: 1.9619861e-10 x: -0.9999888
# y: 1.2556711e-10 x: -0.99999106
# y: 7.993606e-11 x: -0.99999285
# y: 5.1159077e-11 x: -0.9999943
# y: 3.274181e-11 x: -0.9999954
# y: 2.106404e-11 x: -0.9999963
# y: 1.3656631e-11 x: -0.999997
# y: 8.881784e-12 x: -0.9999976
# y: 5.684342e-12 x: -0.9999981
# y: 3.637979e-12 x: -0.99999845
# y: 2.4016344e-12 x: -0.99999875
# y: 1.5667467e-12 x: -0.999999
# y: 1.0267343e-12 x: -0.99999917
# y: 6.963319e-13 x: -0.99999934
# y: 4.2987836e-13 x: -0.99999946
# y: 2.877698e-13 x: -0.9999996
# y: 1.7408297e-13 x: -0.99999964
# y: 1.2789769e-13 x: -0.9999997
# y: 8.881784e-14 x: -0.99999976
# y: 5.684342e-14 x: -0.9999998
# y: 3.1974423e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999
# y: 1.4210855e-14 x: -0.9999999

# %% [markdown]
# ### Definiendo Modelo basado en Clase

# %%
# Datos
X = np.linspace(-2*np.pi, 2*np.pi, 200).reshape(-1, 1)
y_true = np.sin(X)

# %%
class MyModel(tf.keras.Model):
    def __init__(self):
        super(MyModel, self).__init__()
        self.d1 = tf.keras.layers.Dense(64, activation='tanh')
        self.out = tf.keras.layers.Dense(1)

    def call(self, x):
        x = self.d1(x) 
        return self.out(x)

model = MyModel()

# %%
#F = sum((y_true - model(x))**2)
#dF/dW = 0

# %%
# Optimizador and función de perdida
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
loss_fn = tf.keras.losses.MeanSquaredError()

dataset = tf.data.Dataset.from_tensor_slices((X, y_true)).batch(32)

# Training step
@tf.function
def train_step(x_batch, y_batch):
    with tf.GradientTape() as tape:
        predictions = model(x_batch, training=True)
        loss = loss_fn(y_batch, predictions)
    # Calcular gradientes
    gradients = tape.gradient(loss, model.trainable_variables)
    # Aplicar actualización
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

# %%
EPOCHS = 100
for epoch in range(EPOCHS):
    for step, (x_batch, y_batch) in enumerate(dataset):
        loss = train_step(x_batch, y_batch)
    print(f"Epoch {epoch+1}, Loss: {loss.numpy():.4f}")
# Out:
# 2026-07-23 16:42:42.604371: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-07-23 16:42:42.623046: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-07-23 16:42:42.657438: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-07-23 16:42:42.724240: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 1, Loss: 0.1511
# Epoch 2, Loss: 0.2109
# Epoch 3, Loss: 0.4634
# Epoch 4, Loss: 0.0248
# Epoch 5, Loss: 0.1011
# Epoch 6, Loss: 0.2112
# Epoch 7, Loss: 0.0742
# Epoch 8, Loss: 0.2073
# Epoch 9, Loss: 0.1650
# Epoch 10, Loss: 0.1834
# Epoch 11, Loss: 0.2374
# Epoch 12, Loss: 0.2144
# Epoch 13, Loss: 0.2617
# Epoch 14, Loss: 0.2552
# Epoch 15, Loss: 0.2732
# Epoch 16, Loss: 0.2823
# Epoch 17, Loss: 0.2852
# Epoch 18, Loss: 0.2952
# Epoch 19, Loss: 0.2941
# Epoch 20, Loss: 0.2983
# Epoch 21, Loss: 0.2965
# Epoch 22, Loss: 0.2955
# Epoch 23, Loss: 0.2928
# Epoch 24, Loss: 0.2889
# Epoch 25, Loss: 0.2849
# Epoch 26, Loss: 0.2796
# Epoch 27, Loss: 0.2744
# Epoch 28, Loss: 0.2686
# 2026-07-23 16:42:42.827045: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 29, Loss: 0.2628
# Epoch 30, Loss: 0.2568
# Epoch 31, Loss: 0.2509
# Epoch 32, Loss: 0.2450
# Epoch 33, Loss: 0.2392
# Epoch 34, Loss: 0.2336
# Epoch 35, Loss: 0.2281
# Epoch 36, Loss: 0.2228
# Epoch 37, Loss: 0.2176
# Epoch 38, Loss: 0.2127
# Epoch 39, Loss: 0.2080
# Epoch 40, Loss: 0.2035
# Epoch 41, Loss: 0.1992
# Epoch 42, Loss: 0.1950
# Epoch 43, Loss: 0.1910
# Epoch 44, Loss: 0.1872
# Epoch 45, Loss: 0.1836
# 2026-07-23 16:42:43.053684: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 46, Loss: 0.1801
# Epoch 47, Loss: 0.1768
# Epoch 48, Loss: 0.1736
# Epoch 49, Loss: 0.1705
# Epoch 50, Loss: 0.1676
# Epoch 51, Loss: 0.1648
# Epoch 52, Loss: 0.1621
# Epoch 53, Loss: 0.1596
# Epoch 54, Loss: 0.1571
# Epoch 55, Loss: 0.1548
# Epoch 56, Loss: 0.1525
# Epoch 57, Loss: 0.1504
# Epoch 58, Loss: 0.1483
# Epoch 59, Loss: 0.1464
# Epoch 60, Loss: 0.1445
# Epoch 61, Loss: 0.1427
# Epoch 62, Loss: 0.1410
# Epoch 63, Loss: 0.1393
# Epoch 64, Loss: 0.1378
# Epoch 65, Loss: 0.1363
# Epoch 66, Loss: 0.1349
# Epoch 67, Loss: 0.1335
# Epoch 68, Loss: 0.1322
# Epoch 69, Loss: 0.1310
# Epoch 70, Loss: 0.1298
# Epoch 71, Loss: 0.1287
# Epoch 72, Loss: 0.1276
# Epoch 73, Loss: 0.1266
# Epoch 74, Loss: 0.1256
# Epoch 75, Loss: 0.1246
# Epoch 76, Loss: 0.1238
# Epoch 77, Loss: 0.1229
# 2026-07-23 16:42:43.454592: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 78, Loss: 0.1221
# Epoch 79, Loss: 0.1213
# Epoch 80, Loss: 0.1206
# Epoch 81, Loss: 0.1199
# Epoch 82, Loss: 0.1192
# Epoch 83, Loss: 0.1186
# Epoch 84, Loss: 0.1180
# Epoch 85, Loss: 0.1174
# Epoch 86, Loss: 0.1169
# Epoch 87, Loss: 0.1164
# Epoch 88, Loss: 0.1158
# Epoch 89, Loss: 0.1154
# Epoch 90, Loss: 0.1149
# Epoch 91, Loss: 0.1145
# Epoch 92, Loss: 0.1140
# Epoch 93, Loss: 0.1137
# Epoch 94, Loss: 0.1132
# Epoch 95, Loss: 0.1130
# Epoch 96, Loss: 0.1125
# Epoch 97, Loss: 0.1123
# Epoch 98, Loss: 0.1117
# Epoch 99, Loss: 0.1117
# Epoch 100, Loss: 0.1110

# %%
y_pred = model.predict(X)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
plt.plot(X, y_true, label="sin(x)")
plt.plot(X, y_pred, label="NN approx")
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Funciones de Activación
#
# No linealidades comunes:
#
# * Sigmoide: acotada, suave, sufre del problema del gradiente que desaparece.
# * Tanh: centrada en cero, aún presenta desaparición del gradiente para entradas grandes.
# * ReLU: no saturante, activaciones dispersas.
# * GELU: versión suave de ReLU, usada frecuentemente en transformadores.

# %%
# Plots
activations = {
    "sigmoid": tf.nn.sigmoid,
    "tanh": tf.nn.tanh,
    "relu": tf.nn.relu,
    "gelu": tf.nn.gelu
}

x = np.linspace(-5, 5, 200)

plt.figure(figsize=(12,5))
for i, (name, f) in enumerate(activations.items()):
    plt.subplot(1,4,i+1)
    y = f(x).numpy()
    plt.plot(x, y, label=name)
    plt.title(name)
plt.show()

# %% [markdown]
# ## 5. Funciones de Pérdida
#
# En este notebook exploraremos las funciones de pérdida más usadas en *deep learning*,
# su interpretación matemática y cómo implementarlas en TensorFlow/Keras.
#
# ---
#
# ## Contenido
#
# 5.1 Pérdidas para regresión
#
# * MSE
# * MAE
# * Huber
#
# 5.2 Pérdidas para clasificación
#
# * Entropía Cruzada Binaria (*Binary Cross-Entropy*)
# * Entropía Cruzada Categórica (*Categorical Cross-Entropy*)
# * Entropía Cruzada Categórica Dispersa (*Sparse Categorical Cross-Entropy*)
#
# 5.3 Regularización en la pérdida
#
# 5.4 Ejercicios comparativos
#
# ---

# %% [markdown]
# ### 5.1. Pérdidas para Regresión
#
# #### Mean Squared Error (MSE)
# $$
# L = \frac{1}{N}\sum_{i=1}^N (y_i - \hat{y}_i)^2
# $$
#
# Asume que los errores siguen una distribución Gaussiana.
#
# #### Mean Absolute Error (MAE)
# $$
# L = \frac{1}{N}\sum_{i=1}^N |y_i - \hat{y}_i|
# $$
#
# Más robusta a outliers.
#
# #### Huber Loss
# $$
# L_\delta =
# \begin{cases}
# \frac{1}{2}(y - \hat{y})^2 & \text{if } |y - \hat{y}| < \delta \\
# \delta |y - \hat{y}| - \frac{1}{2}\delta^2 & \text{otherwise}
# \end{cases}
# $$
#
# Combina MSE (cerca del error pequeño) y MAE (para outliers).

# %%
# Datos sintéticos
X = np.linspace(-3, 3, 200).reshape(-1, 1)
y_true = 0.5 * X + 1 + 0.3 * np.random.randn(*X.shape)

# Añadimos outliers
y_true[::20] += np.random.randn(*y_true[::20].shape) * 6

plt.scatter(X, y_true, alpha=0.6)
plt.title("Datos sintéticos con outliers")
plt.show()

# %%
def build_reg_model():
    return tf.keras.Sequential([
        tf.keras.layers.Dense(32, activation="relu", input_shape=(1,)),
        tf.keras.layers.Dense(1)
    ])

losses = {
    "MSE": tf.keras.losses.MeanSquaredError(),
    "MAE": tf.keras.losses.MeanAbsoluteError(),
    "Huber": tf.keras.losses.Huber(delta=1.0)
}

histories = {}
preds = {}

for name, loss_fn in losses.items():
    model = build_reg_model()
    model.compile(optimizer="adam", loss=loss_fn)
    h = model.fit(X, y_true, epochs=100, verbose=0)
    histories[name] = h.history['loss']
    preds[name] = model.predict(X)

for name, loss in histories.items():
    plt.plot(loss, label=name)
plt.legend()
plt.title("Comparación de pérdidas en regresión con outliers")
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x763266ff0160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7632642d40d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
plt.scatter(X, y_true, alpha=0.6)
plt.plot(X, preds['MSE'], label="MSE")
plt.plot(X, preds['MAE'], label="MAE")
plt.plot(X, preds['Huber'], label="Huber")
plt.title("Datos sintéticos con outliers")
plt.legend()
plt.show()

# %% [markdown]
# ### 5.2 Pérdidas para Clasificación
#
# #### Binary Cross-Entropy
# $$
# L = - \frac{1}{N} \sum_i \big[ y_i \log \hat{y}_i + (1-y_i)\log(1-\hat{y}_i) \big]
# $$
#
# #### Categorical Cross-Entropy
# $$
# L = - \sum_{i=1}^C y_i \log \hat{y}_i
# $$
#
# #### Sparse Categorical Cross-Entropy
# $$
# L = - \log \hat{y}_i
# $$

# %%
# Supongamos 3 clases
y_true_onehot = np.array([[0, 0, 1],   # clase 2
                          [1, 0, 0]])  # clase 0

y_true_onehot
# Out:
# array([[0, 0, 1],
#        [1, 0, 0]])

# %%
y_true_sparse = np.array([2, 0])       # enteros: clase 2 y clase 0

# %%
# Predicciones (softmax simuladas)
y_pred = np.array([[0.1, 0.2, 0.7], 
                   [0.8, 0.1, 0.1]])

# %%
# Usando categorical_crossentropy (one-hot)
loss_cat = tf.keras.losses.CategoricalCrossentropy()
print("Categorical CE:", loss_cat(y_true_onehot, y_pred).numpy())

# Usando sparse_categorical_crossentropy (etiquetas como enteros)
loss_sparse = tf.keras.losses.SparseCategoricalCrossentropy()
print("Sparse Categorical CE:", loss_sparse(y_true_sparse, y_pred).numpy())
# Out:
# Categorical CE: 0.28990924
# Sparse Categorical CE: 0.28990924

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# Datos clasificación binaria
X, y = make_moons(n_samples=500, noise=0.2, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation="relu", input_shape=(2,)),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model.compile(optimizer="adam",
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=["accuracy"])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, verbose=0)

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Binary Cross-Entropy en clasificación")
plt.show()

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
# Example multiclass: MNIST
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.reshape(-1, 28*28).astype("float32") / 255.0
X_test = X_test.reshape(-1, 28*28).astype("float32") / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", input_shape=(784,)),
    tf.keras.layers.Dense(10, activation="softmax")
])

# Usamos sparse categorical, pues y son enteros [0..9]
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=["accuracy"])

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 2026-07-23 16:43:10.570089: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 2026-07-23 16:43:10.721339: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 2026-07-23 16:43:11.694697: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_95', 4 bytes spill stores, 4 bytes spill loads
# 1841/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8768 - loss: 0.4470
# 2026-07-23 16:43:15.447003: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 2026-07-23 16:43:15.474680: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8777 - loss: 0.4436 - val_accuracy: 0.9607 - val_loss: 0.1338
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9638 - loss: 0.1232 - val_accuracy: 0.9701 - val_loss: 0.1005
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9750 - loss: 0.0815 - val_accuracy: 0.9761 - val_loss: 0.0753
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9827 - loss: 0.0588 - val_accuracy: 0.9743 - val_loss: 0.0810
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9861 - loss: 0.0456 - val_accuracy: 0.9768 - val_loss: 0.0733

# %%
pred = model.predict(X_test)
pred
# Out:
# 2026-07-23 16:43:30.566765: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([[1.9096188e-07, 6.1221015e-09, 1.5916330e-05, ..., 9.9986780e-01,
#         3.3412732e-07, 7.6817408e-08],
#        [2.0743819e-10, 9.2093092e-07, 9.9999678e-01, ..., 7.6674795e-15,
#         3.1479584e-07, 3.8960808e-14],
#        [4.5416832e-06, 9.9517262e-01, 7.9975836e-04, ..., 1.5233300e-03,
#         2.0689527e-03, 2.2829496e-05],
#        ...,
#        [4.7047777e-10, 1.0193663e-09, 4.6226471e-11, ..., 2.6519131e-04,
#         1.8579620e-05, 6.2187866e-04],
#        [6.2398142e-11, 5.8612121e-12, 1.6987781e-12, ..., 1.5906351e-10,
#         9.0291032e-06, 2.8487677e-12],
#        [2.8318402e-07, 5.9064054e-10, 3.3975793e-09, ..., 1.9344769e-12,
#         6.5048918e-11, 1.0040041e-10]], dtype=float32)

# %% [markdown]
# ### 5.3 Loss regularization
#
#
# $$
# L = L_{\text{data}} + \lambda \|W\|^2
# $$

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", 
                          kernel_regularizer=tf.keras.regularizers.l2(1e-4),
                          input_shape=(784,)),
    tf.keras.layers.Dense(10, activation="softmax")
])
