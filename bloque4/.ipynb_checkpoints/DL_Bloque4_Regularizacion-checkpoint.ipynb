# %% [markdown]
# # Regularización en Redes Neuronales con TensorFlow

# %% [markdown]
# ## Cargar dataset

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # Tipos de regularización

# %% [markdown]
# - **L1 (Lasso):**
# Penaliza la suma de los valores absolutos de los pesos. Promueve **sparsity**, realiza selección automática de variables y mejora la interpretabilidad del modelo.
#
# - **L2 (Ridge):**
# Penaliza la suma de los cuadrados de los pesos. Reduce la varianza, estabiliza el entrenamiento y mitiga los efectos de la colinealidad al distribuir los pesos.
#
# - **Elastic Net:**
# Combinación de L1 y L2.
# Mantiene sparsity mientras conserva estabilidad numérica, siendo útil cuando existen variables altamente correlacionadas.

# %% [markdown]
# ## Modelo baseline

# %%
def build_baseline():
    model = models.Sequential([
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

baseline = build_baseline()
history_base = baseline.fit(x_train, y_train, epochs=5, validation_split=0.2)
# Out:
# I0000 00:00:1767713659.768457    6859 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13561 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:07:00.0, compute capability: 8.9
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767713661.130329   12005 service.cc:152] XLA service 0x7a3fb4004cb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767713661.130368   12005 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2026-01-06 09:34:21.186553: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1767713661.349892   12005 cuda_dnn.cc:529] Loaded cuDNN version 91001
# ...

# %% [markdown]
# ## Modelo con L2

# %%
l2 = tf.keras.regularizers.l2(0.001)

def build_l2():
    model = models.Sequential([
        layers.Flatten(),
        layers.Dense(256, activation='relu', kernel_regularizer=l2),
        layers.Dense(128, activation='relu', kernel_regularizer=l2),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model_l2 = build_l2()
history_l2 = model_l2.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.7687 - loss: 0.9941 - val_accuracy: 0.8417 - val_loss: 0.5913
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8461 - loss: 0.5684 - val_accuracy: 0.8642 - val_loss: 0.4967
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8558 - loss: 0.5120 - val_accuracy: 0.8458 - val_loss: 0.5192
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8601 - loss: 0.4816 - val_accuracy: 0.8551 - val_loss: 0.4901
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8672 - loss: 0.4617 - val_accuracy: 0.8527 - val_loss: 0.5020
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8661 - loss: 0.4482 - val_accuracy: 0.8669 - val_loss: 0.4451
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8734 - loss: 0.4288 - val_accuracy: 0.8711 - val_loss: 0.4360
# Epoch 8/10
# ...

# %% [markdown]
# ## Comparación gráfica

# %%
import matplotlib.pyplot as plt

plt.plot(history_base.history['val_accuracy'], label='Baseline')
plt.plot(history_l2.history['val_accuracy'], label='L2')
plt.legend()
plt.show()
