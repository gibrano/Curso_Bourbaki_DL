# %% [markdown]
# # Detección de anomalias usando Autoencoders
#
# Referencia [link](https://keras.io/examples/timeseries/timeseries_anomaly_detection/)

# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers

from matplotlib import pyplot as plt
# Out:
# 2026-01-13 18:25:58.263514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768350358.283092  200171 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768350358.289395  200171 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768350358.304351  200171 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768350358.304377  200171 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768350358.304379  200171 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768350358.304381  200171 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-13 18:25:58.309675: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Datos
#
# Usaremos el conjunto de datos [Numenta Anomaly Benchmark (NAB)](https://www.kaggle.com/boltzmannbrain/nab). Este proporciona series de tiempo artificiales que contienen períodos anómalos de comportamiento etiquetados. Los datos están ordenados, tienen marcas de tiempo y son métricas de un solo valor.
#
# Usaremos el archivo `art_daily_small_noise.csv` para el entrenamiento y el archivo `art_daily_jumpsup.csv` para las pruebas. La simplicidad de este conjunto de datos nos permite demostrar la detección de anomalías de manera efectiva.

# %%
master_url_root = "https://raw.githubusercontent.com/numenta/NAB/master/data/"

df_small_noise_url_suffix = "artificialNoAnomaly/art_daily_small_noise.csv"
df_small_noise_url = master_url_root + df_small_noise_url_suffix
df_small_noise = pd.read_csv(
    df_small_noise_url, parse_dates=True, index_col="timestamp"
)

df_daily_jumpsup_url_suffix = "artificialWithAnomaly/art_daily_jumpsup.csv"
df_daily_jumpsup_url = master_url_root + df_daily_jumpsup_url_suffix
df_daily_jumpsup = pd.read_csv(
    df_daily_jumpsup_url, parse_dates=True, index_col="timestamp"
)

# %%
print(df_small_noise.head())

print(df_daily_jumpsup.head())
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  18.324919
# 2014-04-01 00:05:00  21.970327
# 2014-04-01 00:10:00  18.624806
# 2014-04-01 00:15:00  21.953684
# 2014-04-01 00:20:00  21.909120
#                          value
# timestamp
# 2014-04-01 00:00:00  19.761252
# 2014-04-01 00:05:00  20.500833
# 2014-04-01 00:10:00  19.961641
# 2014-04-01 00:15:00  21.490266
# 2014-04-01 00:20:00  20.187739

# %%
df_daily_jumpsup
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  19.761252
# 2014-04-01 00:05:00  20.500833
# 2014-04-01 00:10:00  19.961641
# 2014-04-01 00:15:00  21.490266
# 2014-04-01 00:20:00  20.187739
# ...                        ...
# 2014-04-14 23:35:00  18.074649
# 2014-04-14 23:40:00  21.002014
# 2014-04-14 23:45:00  20.566713
# 2014-04-14 23:50:00  18.254193
# 2014-04-14 23:55:00  21.863147
#
# [4032 rows x 1 columns]

# %% [markdown]
# ## Visualización de los datos
# ### Series sin anomalías

# %%
fig, ax = plt.subplots()
df_small_noise.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ### Series con anomalías

# %%
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ## Preprocesado
#
# Obtenemos los valores del archivo de datos de la serie de tiempo de entrenamiento y normalizamos los datos de `value`. Tenemos un `value` cada 5 minutos durante 14 días.
#
# * 24 * 60 / 5 = **288 pasos de tiempo por día**
# * 288 * 14 = **4032 puntos de datos** en total"

# %%
training_mean = df_small_noise.mean()
training_std = df_small_noise.std()
df_training_value = (df_small_noise - training_mean) / training_std
print("Número de ejemplos de entrenamiento:", len(df_training_value))
# Out:
# Número de ejemplos de entrenamiento: 4032

# %% [markdown]
# ### Creación de secuancias

# %%
TIME_STEPS = 288


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
# Out:
# Training input shape:  (3745, 288, 1)

# %% [markdown]
# ## Construcción del modelo

# %%
ht = [1,0,5,2]

[
[1,0,5,2]
[1,0,5,2]
[1,0,5,2]
[1,0,5,2]
[1,0,5,2]
]

# %% [markdown]
# minimizar $||x - \hat{x}||$
#
#
# $\hat{x} = f(x)$

# %%
# LSTM Autoencoder
model = tf.keras.Sequential([
    # Encoder
    layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
    layers.LSTM(64, activation='tanh', return_sequences=True),
    layers.Dropout(0.2),
    layers.LSTM(32, activation='tanh', return_sequences=True),
    
    # Encaje
    layers.Dropout(0.2),
    layers.LSTM(16, activation='tanh', return_sequences=False), 
    layers.RepeatVector(x_train.shape[1]),
    
    # Decoder
    layers.LSTM(32, activation='tanh', return_sequences=True),
    layers.Dropout(0.2),
    layers.LSTM(64, activation='tanh', return_sequences=True),
    layers.TimeDistributed(layers.Dense(x_train.shape[2]))
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss="mse")
model.summary()
# Out:
# I0000 00:00:1768350362.872738  200171 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13851 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:07:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 288, 64)        │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 288, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 288, 32)        │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 288, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 16)             │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 288, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 288, 32)        │         6,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 288, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 288, 64)        │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 288, 1)         │            65 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,617 (248.50 KB)
#  Trainable params: 63,617 (248.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Entrenamiento

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=100,
    batch_size=128,
    validation_split=0.1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")
    ],
)
# Out:
# Epoch 1/100
# I0000 00:00:1768350372.718700  200329 cuda_dnn.cc:529] Loaded cuDNN version 91001
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 160ms/step - loss: 0.9981 - val_loss: 1.0077
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.9960 - val_loss: 1.0036
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.9874 - val_loss: 0.9933
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.9648 - val_loss: 0.9832
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.9504 - val_loss: 0.9605
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.9275 - val_loss: 0.9240
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.8972 - val_loss: 0.9059
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.8770 - val_loss: 0.8913
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.8719 - val_loss: 0.8804
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.8598 - val_loss: 0.8752
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.8525 - val_loss: 0.8620
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.8411 - val_loss: 0.7940
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.7432 - val_loss: 0.6167
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.6029 - val_loss: 0.5129
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.5470 - val_loss: 0.4842
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.5113 - val_loss: 0.4921
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.4727 - val_loss: 0.4142
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.4395 - val_loss: 0.3732
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3923 - val_loss: 0.3467
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3422 - val_loss: 0.1925
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2384 - val_loss: 0.2157
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2269 - val_loss: 0.1848
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1993 - val_loss: 0.1520
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1866 - val_loss: 0.1418
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1828 - val_loss: 0.1657
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.1835 - val_loss: 0.1523
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1795 - val_loss: 0.1531
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1711 - val_loss: 0.1260
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1596 - val_loss: 0.1252
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1531 - val_loss: 0.1113
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1483 - val_loss: 0.1218
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1458 - val_loss: 0.1078
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.1353 - val_loss: 0.1013
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1373 - val_loss: 0.1015
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1315 - val_loss: 0.0985
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.1309 - val_loss: 0.1042
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1315 - val_loss: 0.0952
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1277 - val_loss: 0.0929
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1205 - val_loss: 0.0919
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1196 - val_loss: 0.0909
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.1222 - val_loss: 0.0874
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1166 - val_loss: 0.0895
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1133 - val_loss: 0.0879
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.1129 - val_loss: 0.0852
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1107 - val_loss: 0.0894
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1107 - val_loss: 0.0839
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.1074 - val_loss: 0.0795
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1078 - val_loss: 0.0787
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1067 - val_loss: 0.0761
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1039 - val_loss: 0.0773
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1027 - val_loss: 0.0854
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.1033 - val_loss: 0.0764
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1015 - val_loss: 0.0731
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0979 - val_loss: 0.0740
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0969 - val_loss: 0.0771
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0973 - val_loss: 0.0730
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0943 - val_loss: 0.0722
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0938 - val_loss: 0.0726
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0956 - val_loss: 0.0713
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0918 - val_loss: 0.0676
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0923 - val_loss: 0.0674
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0897 - val_loss: 0.0714
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0898 - val_loss: 0.0645
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0904 - val_loss: 0.0676
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0884 - val_loss: 0.0691
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0875 - val_loss: 0.0667
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0868 - val_loss: 0.0695
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0872 - val_loss: 0.0665

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detectando anomalías
#
# Detectaremos anomalías determinando qué tan bien nuestro modelo puede reconstruir los datos de entrada.
#
# 1. Calcular la pérdida MAE en las muestras de entrenamiento.
# 2. Encontrar el valor máximo de la pérdida MAE. Este es el peor desempeño de nuestro modelo al intentar reconstruir una muestra. Usaremos este valor como el `umbral` para la detección de anomalías.
# 3. Si la pérdida de reconstrucción para una muestra es mayor que este valor `umbral`, entonces podemos inferir que el modelo está observando un patrón con el que no está familiarizado. Etiquetaremos esta muestra como una `anomalía`.

# %%
# Obtenemos el MAE.
x_train_pred = model.predict(x_train)
train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

threshold = np.quantile(train_mae_loss,0.99) #np.max(train_mae_loss)
print("Reconstrucción del umbral de error: ", threshold)
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step
# Reconstrucción del umbral de error:  0.2697817182990098

# %%
len(train_mae_loss)
# Out:
# 3745

# %% [markdown]
# ### Comparar reconstrucción
#
# Veamos cómo nuestro modelo ha reconstruido la primera muestra.
# Esta corresponde a los **288 pasos de tiempo del día 1** de nuestro conjunto de entrenamiento.

# %%
# Checking how the first sequence is learnt
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# ### Preparación de los datos test

# %%
df_test_value = (df_daily_jumpsup - training_mean) / training_std
fig, ax = plt.subplots()
df_test_value.plot(legend=False, ax=ax)
plt.show()

x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Test input shape:  (3745, 288, 1)

# %%
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = test_mae_loss > threshold
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step
# Number of anomaly samples:  407
# Indices of anomaly samples:  (array([ 202,  203,  204,  489,  490,  776,  777,  778,  779, 1067, 1068,
#        1354, 1355, 1356, 1641, 1642, 1643, 1927, 1928, 1929, 2216, 2217,
#        2218, 2506, 2507, 2508, 2712, 2713, 2714, 2715, 2716, 2717, 2718,
#        2719, 2720, 2721, 2722, 2723, 2724, 2725, 2726, 2727, 2728, 2729,
#        2730, 2731, 2732, 2733, 2734, 2735, 2736, 2737, 2738, 2739, 2740,
#        2741, 2742, 2743, 2744, 2745, 2746, 2747, 2748, 2749, 2750, 2751,
#        2752, 2753, 2754, 2755, 2756, 2757, 2758, 2759, 2760, 2761, 2762,
#        2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771, 2772, 2773,
#        2774, 2775, 2776, 2777, 2778, 2779, 2780, 2781, 2782, 2783, 2784,
#        2785, 2786, 2787, 2788, 2789, 2790, 2791, 2792, 2793, 2794, 2795,
#        2796, 2797, 2798, 2799, 2800, 2801, 2802, 2803, 2804, 2805, 2806,
#        2807, 2808, 2809, 2810, 2811, 2812, 2813, 2814, 2815, 2816, 2817,
#        2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825, 2826, 2827, 2828,
#        2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836, 2837, 2838, 2839,
#        2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847, 2848, 2849, 2850,
#        2851, 2852, 2853, 2854, 2855, 2856, 2857, 2858, 2859, 2860, 2861,
#        2862, 2863, 2864, 2865, 2866, 2867, 2868, 2869, 2870, 2871, 2872,
#        2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881, 2882, 2883,
#        2884, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892, 2893, 2894,
#        2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903, 2904, 2905,
#        2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914, 2915, 2916,
#        2917, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925, 2926, 2927,
#        2928, 2929, 2930, 2931, 2932, 2933, 2934, 2935, 2936, 2937, 2938,
#        2939, 2940, 2941, 2942, 2943, 2944, 2945, 2946, 2947, 2948, 2949,
#        2950, 2951, 2952, 2953, 2954, 2955, 2956, 2957, 2958, 2959, 2960,
#        2961, 2962, 2963, 2964, 2965, 2966, 2967, 2968, 2969, 2970, 2971,
#        2972, 2973, 2974, 2975, 2976, 2977, 2978, 2979, 2980, 2981, 2982,
#        2983, 2984, 2985, 2986, 2987, 2988, 2989, 2990, 2991, 2992, 2993,
#        2994, 2995, 2996, 2997, 2998, 2999, 3000, 3001, 3002, 3003, 3004,
#        3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013, 3014, 3015,
#        3016, 3017, 3018, 3019, 3020, 3021, 3022, 3023, 3024, 3025, 3026,
#        3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035, 3036, 3037,
#        3038, 3039, 3040, 3041, 3042, 3043, 3044, 3045, 3046, 3047, 3048,
#        3049, 3050, 3051, 3052, 3053, 3054, 3055, 3056, 3057, 3058, 3059,
#        3060, 3061, 3062, 3063, 3064, 3065, 3066, 3067, 3068, 3069, 3070,
#        3071, 3072, 3073, 3074, 3075, 3076, 3077, 3078, 3079, 3080, 3081,
#        3082, 3083, 3084, 3085, 3086, 3087, 3368, 3369, 3370, 3657, 3658]),)

# %% [markdown]
# ## Plot de anomalías
#
# Ahora ya conocemos las muestras de los datos que son anomalías. Con esto, encontraremos las `timestamps` correspondientes a partir de los datos originales de prueba. Usaremos el siguiente método para hacerlo:
#
# Supongamos que **time_steps = 3** y tenemos **10 valores de entrenamiento**. Nuestro `x_train` se verá así:
#
# * 0, 1, 2
# * 1, 2, 3
# * 2, 3, 4
# * 3, 4, 5
# * 4, 5, 6
# * 5, 6, 7
# * 6, 7, 8
# * 7, 8, 9
#
# Excepto los valores iniciales y finales (time_steps - 1), todos los demás aparecerán en `time_steps` muestras distintas. Por lo tanto, si sabemos que las muestras
# [(3, 4, 5), (4, 5, 6), (5, 6, 7)]
# son anomalías, podemos decir que el punto de dato **5** es una anomalía.

# %%
anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)

# %%
df_subset = df_daily_jumpsup.iloc[anomalous_data_indices]
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
df_subset.plot(legend=False, ax=ax, color="r")
plt.show()
