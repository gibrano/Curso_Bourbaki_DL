# %% [markdown]
# # Autoencoder para Detección de Fraude con Tarjetas de Crédito
#
# Este notebook implementa un autoencoder en TensorFlow para el dataset de fraude [link](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud/data).

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from matplotlib import pyplot as plt

# %% [markdown]
# ## Cargar dataset

# %%
df = pd.read_csv('../data/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
print("Missing values per column:")
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# Missing values per column:
# Time      0
# V16       0
# Amount    0
# V28       0
# V27       0
# V26       0
# V25       0
# V24       0
# V23       0
# V22       0
# V21       0
# V20       0
# V19       0
# V18       0
# V17       0
# V15       0
# V1        0
# V14       0
# V13       0
# V12       0
# V11       0
# V10       0
# V9        0
# V8        0
# V7        0
# V6        0
# V5        0
# V4        0
# V3        0
# V2        0
# Class     0
# dtype: int64

# %%
print("\nClass distribution:")
print(df['Class'].value_counts(normalize=True).rename('proportion'))
# Out:
# Class distribution:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
X = df.drop('Class', axis=1).values
y = df['Class'].values

# %% [markdown]
# ## Preprocesamiento

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## División de train/test y selección de datos normales

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train_normal = X_train[y_train == 0]

# %% [markdown]
# ## Modelo Autoencoder

# %%
input_dim = X_train_normal.shape[1]
inputs = tf.keras.Input(shape=(input_dim,))
encoded = tf.keras.layers.Dense(64, activation='relu')(inputs)
encoded = tf.keras.layers.Dense(32, activation='relu')(encoded)

bottleneck = tf.keras.layers.Dense(16, activation='relu')(encoded)

decoded = tf.keras.layers.Dense(32, activation='relu')(bottleneck)
decoded = tf.keras.layers.Dense(64, activation='relu')(decoded)
outputs = tf.keras.layers.Dense(input_dim, activation='linear')(decoded)


autoencoder = tf.keras.Model(inputs, outputs)
autoencoder.compile(optimizer='adam', loss='mse')
# Out:
# I0000 00:00:1789085175.952880 1281691 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12397 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:07:00.0, compute capability: 8.9

# %% [markdown]
# ## Entrenamiento

# %%
history = autoencoder.fit(X_train_normal, X_train_normal, epochs=20, batch_size=256, validation_split=0.1, shuffle=True)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789085178.132978 1322472 service.cc:152] XLA service 0x76482400cd50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1789085178.133007 1322472 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2026-09-10 18:06:18.192553: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1789085178.419040 1322472 cuda_dnn.cc:529] Loaded cuDNN version 91001
# 2026-09-10 18:06:20.359281: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_245', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-09-10 18:06:20.588395: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_245', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-09-10 18:06:20.748537: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_409', 24 bytes spill stores, 24 bytes spill loads
#
# 2026-09-10 18:06:21.120069: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_471', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-09-10 18:06:21.733435: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_479', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-09-10 18:06:22.750351: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_477', 88 bytes spill stores, 88 bytes spill loads
#  72/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9591
# I0000 00:00:1789085185.005409 1322472 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 779/800 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6126
# 2026-09-10 18:06:28.266499: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_245', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-09-10 18:06:28.723790: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_245', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-09-10 18:06:29.706889: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_471', 732 bytes spill stores, 732 bytes spill loads
#
# 2026-09-10 18:06:29.790956: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_477', 480 bytes spill stores, 480 bytes spill loads
#
# 2026-09-10 18:06:30.408627: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_479', 52 bytes spill stores, 52 bytes spill loads
#
# 2026-09-10 18:06:30.715897: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_479', 900 bytes spill stores, 900 bytes spill loads
#
# 2026-09-10 18:06:30.954548: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_477', 144 bytes spill stores, 144 bytes spill loads
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6072
# 2026-09-10 18:06:34.850384: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_49', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-09-10 18:06:35.571402: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_49', 8 bytes spill stores, 8 bytes spill loads
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - loss: 0.6069 - val_loss: 0.1802
# Epoch 2/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1606 - val_loss: 0.1165
# Epoch 3/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1114 - val_loss: 0.0943
# Epoch 4/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0966 - val_loss: 0.0845
# Epoch 5/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0822 - val_loss: 0.0729
# Epoch 6/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0768 - val_loss: 0.0681
# Epoch 7/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0664 - val_loss: 0.0634
# Epoch 8/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0627 - val_loss: 0.0589
# Epoch 9/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0570 - val_loss: 0.0559
# Epoch 10/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0558 - val_loss: 0.0525
# Epoch 11/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0528 - val_loss: 0.0506
# Epoch 12/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0494 - val_loss: 0.0483
# Epoch 13/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0474 - val_loss: 0.0451
# Epoch 14/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0451 - val_loss: 0.0448
# Epoch 15/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0454 - val_loss: 0.0423
# Epoch 16/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0440 - val_loss: 0.0416
# Epoch 17/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0439 - val_loss: 0.0410
# Epoch 18/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0422
# Epoch 19/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0408 - val_loss: 0.0393
# Epoch 20/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0387 - val_loss: 0.0394

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
])

# %%
model2
# Out:
# <Sequential name=sequential_1, built=True>

# %%
w1 = autoencoder.layers[1].get_weights()
w2 = autoencoder.layers[2].get_weights()
w3 = autoencoder.layers[3].get_weights()

# %%
model2.layers[0].set_weights(w1)
model2.layers[1].set_weights(w2)
model2.layers[2].set_weights(w3)

# %%
X_train_normal[:1]
# Out:
# array([[ 1.02211246,  0.99813578, -0.23059493, -0.20775754,  0.23318268,
#         -0.36904644, -0.06469975, -0.50762449,  0.03013664,  0.95988654,
#         -0.02795739,  0.61231399,  1.69285059,  1.26175537, -0.2642062 ,
#         -0.36238366,  0.35064408, -1.09596692,  0.77748202,  0.20636189,
#         -0.16264904,  0.32428871,  1.3343042 ,  0.08520655, -0.46000718,
#         -0.0863251 , -0.4495408 ,  0.11190459, -0.14282722, -0.31328851]])

# %%
model2(X_train_normal[:1])
# Out:
# <tf.Tensor: shape=(1, 16), dtype=float32, numpy=
# array([[0.       , 5.2283144, 2.8436484, 3.4540687, 1.198123 , 4.559043 ,
#         3.2142453, 4.990258 , 2.6101496, 4.1090474, 4.6992555, 2.7234902,
#         5.064227 , 1.9987931, 3.1859403, 2.3428278]], dtype=float32)>

# %% [markdown]
# ## Errores de reconstrucción y umbral

# %%
x_train_pred = autoencoder.predict(X_train_normal)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train_normal), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()
# Out:
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step

# %%
threshold = np.quantile(train_mae_loss, [0.95])[0]
threshold
# Out:
# 0.31525064639116795

# %%
X_test_pred = autoencoder.predict(X_test)
reconstruction_error = np.mean(np.abs(X_test - X_test_pred), axis=1)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 868us/step

# %%
reconstruction_error
# Out:
# array([1.73253601, 0.13427923, 0.03785795, ..., 0.17112069, 0.08382362,
#        0.53199559])

# %% [markdown]
# ## Clasificación y métricas

# %%
y_pred = (reconstruction_error > threshold).astype(int)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     56864
#            1       0.03      0.87      0.06        98
#
#     accuracy                           0.95     56962
#    macro avg       0.51      0.91      0.51     56962
# weighted avg       1.00      0.95      0.97     56962

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[53999  2865]
#  [   13    85]]

# %%
y_pred = (reconstruction_error > 0.5).astype(int)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.09      0.81      0.16        98
#
#     accuracy                           0.99     56962
#    macro avg       0.54      0.90      0.58     56962
# weighted avg       1.00      0.99      0.99     56962

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[56061   803]
#  [   19    79]]
